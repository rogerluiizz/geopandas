# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

# %%
apps_vca = gpd.read_file(r'C:\Users\Samsung\Desktop\Geoprocessamento - ARCGIS\SHAPES\VITORIA DA CONQUISTA\APP\APP_VCA.shp', encoding='utf-8')

# %%
apps_vca['NOM_TEMA'].unique()
# Out:
# array(['Ã\x81rea de PreservaÃ§Ã£o Permanente de Rios atÃ© 10 metros',
#        'Ã\x81rea de PreservaÃ§Ã£o Permanente de Veredas',
#        'Ã\x81rea de PreservaÃ§Ã£o Permanente de Lagos e Lagoas Naturais',
#        "Ã\x81rea de PreservaÃ§Ã£o Permanente de Nascentes ou Olhos D'Ã¡gua Perenes",
#        'Ã\x81rea de PreservaÃ§Ã£o Permanente de Ã\x81reas com Declividades Superiores a 45 graus',
#        'Ã\x81rea de PreservaÃ§Ã£o Permanente de Rios de 10 atÃ© 50 metros',
#        'Ã\x81rea de PreservaÃ§Ã£o Permanente de ReservatÃ³rio artificial decorrente de barramento de cu',
#        'Ã\x81rea de PreservaÃ§Ã£o Permanente a Recompor de Lagos e Lagoas Naturais',
#        'Ã\x81rea de PreservaÃ§Ã£o Permanente a Recompor de Rios atÃ© 10 metros',
#        'APP segundo art. 61-A da Lei 12.651 de 2012',
#        'Ã\x81rea de PreservaÃ§Ã£o Permanente em Ã¡rea antropizada nÃ£o declarada como Ã¡rea consoli',
#        'Ã\x81rea de PreservaÃ§Ã£o Permanente em Ã¡rea de VegetaÃ§Ã£o Nativa',
# ...

# %%
plt.rcParams['figure.figsize'] = [20, 10] # Aumenta o tamanho da dimensão do gráfico
apps_vca.plot(cmap = 'jet', edgecolor = 'black', column = 'NOM_TEMA')
# Out:
# <AxesSubplot:>

# %%
vca = gpd.read_file(r'C:\Users\Samsung\Desktop\Geoprocessamento - ARCGIS\SHAPES\VITORIA DA CONQUISTA\APP\VCA.shp', 
encoding='utf-8')
vca.plot(color = 'none', edgecolor = 'black', linewidth = 2)
# Out:
# <AxesSubplot:>

# %%
apps_vca.isnull().sum()
# Out:
# IDF           0
# NOM_TEMA      0
# NUM_AREA      0
# Shape_Leng    0
# Shape_Area    0
# geometry      0
# dtype: int64

# %%
apps_vca.columns
# Out:
# Index(['IDF', 'NOM_TEMA', 'NUM_AREA', 'Shape_Leng', 'Shape_Area', 'geometry'], dtype='object')

# %%
apps_vca.head()
# Out:
#         IDF                                           NOM_TEMA  NUM_AREA  \
# 0  300278.0  Ãrea de PreservaÃ§Ã£o Permanente de Rios atÃ©...     11.82
# 1  494204.0  Ãrea de PreservaÃ§Ã£o Permanente de Rios atÃ©...     15.33
# 2  494227.0  Ãrea de PreservaÃ§Ã£o Permanente de Rios atÃ©...      3.60
# 3  509865.0  Ãrea de PreservaÃ§Ã£o Permanente de Rios atÃ©...      5.18
# 4  512393.0  Ãrea de PreservaÃ§Ã£o Permanente de Rios atÃ©...      0.75
#
#     Shape_Leng     Shape_Area  \
# 0  7142.745770  118239.642502
# 1  5932.010341  153331.478301
# 2  1519.652882   36017.000000
# 3  2686.516242   51760.500000
# 4   580.518407    7520.000000
#
#                                             geometry
# 0  POLYGON ((294217.743 8325205.776, 294092.744 8...
# 1  POLYGON ((281391.956 8352091.942, 281390.956 8...
# 2  POLYGON ((296125.000 8330742.000, 296064.000 8...
# 3  POLYGON ((301875.000 8331779.000, 301900.000 8...
# 4  POLYGON ((302029.000 8332495.000, 302047.000 8...

# %%
apps_vca.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 875 entries, 0 to 874
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   IDF         875 non-null    float64
#  1   NOM_TEMA    875 non-null    object
#  2   NUM_AREA    875 non-null    float64
#  3   Shape_Leng  875 non-null    float64
#  4   Shape_Area  875 non-null    float64
#  5   geometry    875 non-null    geometry
# dtypes: float64(4), geometry(1), object(1)
# memory usage: 41.1+ KB

# %%
plt.rcParams['figure.figsize'] = [30, 10] #aumentar o tamanho do gráfico
plt.rcParams.update({'font.size': 22}) #aumentar o tamanho da fonte
apps_vca['NOM_TEMA'].value_counts().plot(kind='bar')
plt.title('Tipos de APPs em Vitória da Conquista') #titulo
plt.ylabel('Quantidade') #eixo y
# Out:
# Text(0, 0.5, 'Quantidade')

# %%
fig, ax = plt.subplots(1,1, figsize=(20, 10))
vca.plot(ax = ax, color = 'none', edgecolor = 'black', linewidth = 2)
apps_vca.plot(ax = ax, color = 'green', edgecolor = 'green', column = 'NOM_TEMA')
# Out:
# c:\Users\Samsung\anaconda3\lib\site-packages\geopandas\plotting.py:641: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   warnings.warn(
# <AxesSubplot:>

# %%
apps_vca.crs
# Out:
# <Projected CRS: EPSG:31984>
# Name: SIRGAS 2000 / UTM zone 24S
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Brazil - 42°W to 36°W
# - bounds: (-42.0, -26.35, -36.0, 0.74)
# Coordinate Operation:
# - name: UTM zone 24S
# - method: Transverse Mercator
# Datum: Sistema de Referencia Geocentrico para las AmericaS 2000
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
vca.crs
# Out:
# <Projected CRS: EPSG:31984>
# Name: SIRGAS 2000 / UTM zone 24S
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Brazil - 42°W to 36°W
# - bounds: (-42.0, -26.35, -36.0, 0.74)
# Coordinate Operation:
# - name: UTM zone 24S
# - method: Transverse Mercator
# Datum: Sistema de Referencia Geocentrico para las AmericaS 2000
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
APP_VCA_Interesse = gpd.overlay(apps_vca, vca, how='intersection')

# %%
fig, ax = plt.subplots(1,1, figsize=(20, 10))
vca.plot(ax = ax, color = 'none', edgecolor = 'black', linewidth = 2)
APP_VCA_Interesse.plot(ax = ax, color = 'green', edgecolor = 'green', column = 'NOM_TEMA')
# Out:
# c:\Users\Samsung\anaconda3\lib\site-packages\geopandas\plotting.py:641: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   warnings.warn(
# <AxesSubplot:>

# %%
APP_VCA_Interrese.head()
# Out:
#         IDF                                           NOM_TEMA  NUM_AREA  \
# 0  300278.0  Ãrea de PreservaÃ§Ã£o Permanente de Rios atÃ©...     11.82
# 1  494204.0  Ãrea de PreservaÃ§Ã£o Permanente de Rios atÃ©...     15.33
# 2  494227.0  Ãrea de PreservaÃ§Ã£o Permanente de Rios atÃ©...      3.60
# 3  509865.0  Ãrea de PreservaÃ§Ã£o Permanente de Rios atÃ©...      5.18
# 4  512393.0  Ãrea de PreservaÃ§Ã£o Permanente de Rios atÃ©...      0.75
#
#     Shape_Leng     Shape_Area   CD_MUN                NM_MUN SIGLA_UF  \
# 0  7142.745770  118239.642502  2933307  Vitória da Conquista       BA
# 1  5932.010341  153331.478301  2933307  Vitória da Conquista       BA
# 2  1519.652882   36017.000000  2933307  Vitória da Conquista       BA
# 3  2686.516242   51760.500000  2933307  Vitória da Conquista       BA
# 4   580.518407    7520.000000  2933307  Vitória da Conquista       BA
#
#    AREA_KM2                                           geometry
# ...

# %%
APP_VCA_Interesse.to_file(r'C:\Users\Samsung\Desktop\Geoprocessamento - ARCGIS\SHAPES\VITORIA DA CONQUISTA\APP\APP_VCA_Interrese.shp')
# Out:
# c:\Users\Samsung\anaconda3\lib\site-packages\geopandas\io\file.py:299: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
